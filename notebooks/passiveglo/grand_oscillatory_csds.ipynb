# %%
# %cd ../..
# Out:
# /home/eli/AnacondaProjects/epych

# %%
# %env DASK_LOGGING__DISTRIBUTED=CRITICAL
# %env OMPI_MCA_btl_sm_backing_directory=/mnt/data/tmp_storage
# %env SPYTMPDIR=/mnt/data/tmp_storage
# %env SPYLOGLEVEL=CRITICAL
# %env SPYPARLOGLEVEL=CRITICAL
# Out:
# env: DASK_LOGGING__DISTRIBUTED=CRITICAL
# env: OMPI_MCA_btl_sm_backing_directory=/mnt/data/tmp_storage
# env: SPYTMPDIR=/mnt/data/tmp_storage
# env: SPYLOGLEVEL=CRITICAL
# env: SPYPARLOGLEVEL=CRITICAL

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import collections
from fooof import FOOOF
import functools
import itertools
import logging
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import quantities as pq

import epych
from epych.statistics import alignment, spectrum
# Out:
# /tmp/ipykernel_3556282/3643940196.py:2: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   from fooof import FOOOF
# [striatum:3556282] shmem: mmap: an error occurred while determining whether or not /tmp/ompi.striatum.1000/jf.0/3549691904/shared_mem_cuda_pool.striatum could be created.
# [striatum:3556282] create_and_attach: unable to create shared memory BTL coordinating structure :: size 134217728

# %%
# %matplotlib inline

# %%
logging.basicConfig(level=logging.INFO)

# %%
ADAPTED_ONSET = pq.Quantity(-1.0) * pq.second
ADAPTED_OFFSET = pq.Quantity(-0.5) * pq.second
ODDBALL_ONSET = pq.Quantity(-1.9017372477960602e-14) * pq.second
ODDBALL_OFFSET = pq.Quantity(0.5004545430388676) * pq.second
OFFSET = pq.Quantity(0.050) * pq.second
EVENTS = {
    "Oddball": (ODDBALL_ONSET.magnitude, 'lightgreen'),
    "Offset": (ODDBALL_OFFSET.magnitude, 'red'),
}
FORCE_RECOMPUTE = False

# %%
CONDITIONS = ["lonaive", "go_gloexp", "go_seqctl", "lo_gloexp", "lo_rndctl", "igo_seqctl"]
CONTRASTS = [("go_contrast", "go_gloexp", "go_seqctl"), ("ssa", "lo_gloexp", "igo_seqctl"), ("dd", "lo_rndctl", "lonaive")]

# %%
CONDITION_TITLES = {
    "lonaive": "Habituation",
    "go_gloexp": "xxxX [B1]",
    "go_seqctl": "xxxx [B3]",
    "lo_gloexp": "xxxY [B1]",
    "lo_rndctl": "XXXY [B2]",
    "igo_seqctl": "yyyy [B3]"
}
CONTRAST_TITLES = {
    "go_contrast": "Global Oddball",
    "ssa": "Stimulus Specific Adaptation",
    "dd": "Deviance Detection"
}

# %%
AREA_TITLES = {
    "VISal": "AL",
    "VISam": "AM",
    "VISl": "LM",
    "VISp": "V1",
    "VISpm": "PM",
    "VISrl": "RL",
}
def stattitle(name, stat):
    if name in AREA_TITLES:
        return AREA_TITLES[name]
    return name
ANATOMICAL_AREAS = ['VISp', 'VISl', 'VISrl', 'VISal', 'VISpm', 'VISam']

# %%
FREQ_RANGE = (spectrum.THETA_BAND[0].magnitude, spectrum.GAMMA_BAND[1].magnitude)

# %%
OSCILLATORY_BAND_NAMES = {
    (4, 8): ("theta", "$\\theta$", lambda loc: True),
    (12, 24): ("alphabeta", "$\\alpha/\\beta$", lambda loc: "5" in loc or "6" in loc),
    (30, 50): ("gamma", "$\\gamma$", lambda loc: "2/3" in loc or "4" in loc),
}

# %%
OSCILLATORY_BAND_CBARLIMS = {
    (4, 8): 4,
    (12, 24): 4,
    (30, 50): 4,
}
OSCILLATORY_BAND_SIGNAL_WIDTH = {
    (4, 8): 8,
    (12, 24): 6,
    (30, 50): 6,
}

# %%
def oddball(signal):
    return signal[(ODDBALL_ONSET - OFFSET).magnitude:(ODDBALL_OFFSET + OFFSET).magnitude].fmap(lambda data: data.rescale("uV"))

# %%
oddball_band_oscillations = {
    cond: {
        band: {area: None for area in ANATOMICAL_AREAS} for band in OSCILLATORY_BAND_NAMES
    }
    for cond in CONDITIONS
}
oddball_band_csds = {cond: {band: None for band in OSCILLATORY_BAND_NAMES} for cond in CONDITIONS}

# %%
for cond in CONDITIONS:
    logging.info("Finding oscillatory troughs across condition %s" % cond)
    sampling = epych.recording.Sampling.unpickle("/mnt/data/000253/grandcat_%s" % cond)
    logging.info("Loaded LFPs for condition %s" % cond)
    oddballs = sampling.smap(oddball)
    del sampling
    oddballs._signals = {k: v for k, v in oddballs.signals.items() if k in ANATOMICAL_AREAS}
    for band, (_, _, selector) in OSCILLATORY_BAND_NAMES.items():
        os.makedirs("/mnt/data/000253/oscillatory_phases", exist_ok=True)

        if os.path.exists("/mnt/data/000253/oscillatory_phases/%s_%s" % (cond, band)) and not FORCE_RECOMPUTE:
            phases = epych.recording.Sampling.unpickle("/mnt/data/000253/oscillatory_phases/%s_%s" % (cond, band))
        else:
            phases = oddballs.smap(lambda sig: sig.select_channels([selector(loc) for loc in sig.channels.location.values]).band_phases(band[0] * pq.Hz, band[1] * pq.Hz))
            phases.pickle("/mnt/data/000253/oscillatory_phases/%s_%s" % (cond, band))

        period = 1 / ((band[0] + band[1]) / 2) * pq.second * 1.5
        for area in ANATOMICAL_AREAS:
            oddball_band_oscillations[cond][band][area] = oddballs.signals[area].epoch_oscillations(period, phases.signals[area])
# Out:
# INFO:root:Finding oscillatory troughs across condition lonaive
# INFO:root:Loaded LFPs for condition lonaive
# INFO:root:Finding oscillatory troughs across condition go_gloexp
# INFO:root:Loaded LFPs for condition go_gloexp
# INFO:root:Finding oscillatory troughs across condition go_seqctl
# INFO:root:Loaded LFPs for condition go_seqctl
# INFO:root:Finding oscillatory troughs across condition lo_gloexp
# INFO:root:Loaded LFPs for condition lo_gloexp
# INFO:root:Finding oscillatory troughs across condition lo_rndctl
# INFO:root:Loaded LFPs for condition lo_rndctl
# INFO:root:Finding oscillatory troughs across condition igo_seqctl
# INFO:root:Loaded LFPs for condition igo_seqctl

# %%
def events_callback(self, ax, events={}):
    for (event, (time, color)) in events.items():
        ymin, ymax = ax.get_ybound()
        xtime = self.sample_at(time)
        ax.vlines(xtime, ymin, ymax, colors=color, linestyles='dashed', label=event)
        ax.annotate(event, (xtime + 0.5, ymax - 2))

# %%
for cond in CONDITIONS:
    logging.info("Plotting oscillatory CSDs for condition %s" % cond)
    os.makedirs(cond, exist_ok=True)
    for band, (name, latex, _) in OSCILLATORY_BAND_NAMES.items():
        logging.info("Plotting oscillatory CSDs for band %s" % OSCILLATORY_BAND_NAMES[band][0])
        os.makedirs("%s/%s" % (cond, OSCILLATORY_BAND_NAMES[band][0]), exist_ok=True)
        period = 1 / ((band[0] + band[1]) / 2) * pq.second

        area_csds = {}
        for area in ANATOMICAL_AREAS:
            threshold = oddball_band_oscillations[cond][band][area].downsample(4).current_source_density(depth_column="vertical", method=None).significance_threshold()
            area_csds[area] = oddball_band_oscillations[cond][band][area].downsample(4).current_source_density(depth_column="vertical", method=None).evoked()
            area_csds[area] = oddball_band_oscillations[cond][band][area].evoked().downsample(4).current_source_density(depth_column="vertical").fmap(
                lambda data: data.rescale("uA/(cm^2)") * (np.abs(area_csds[area].data.magnitude) > threshold)
            )
        oddball_band_csds[cond][band] = epych.recording.EvokedSampling(epych.recording.empty_intervals(), epych.recording.empty_trials(), epych.recording.default_units(), **area_csds)

        oddball_band_csds[cond][band].plot(cmap="jet_r", title="%s-oscillation Current Source Density (%s)" % (latex, CONDITION_TITLES[cond]),
                                           figure=cond + "/%s_csd.svg" % OSCILLATORY_BAND_NAMES[band][0],
                                           vmin=-OSCILLATORY_BAND_CBARLIMS[band], vmax=OSCILLATORY_BAND_CBARLIMS[band],
                                           sigtitle=lambda area, signal: AREA_TITLES[area],
                                           width_per_signal=OSCILLATORY_BAND_SIGNAL_WIDTH[band],
                                           **{'Cycle start': (-period.item()/2, 'g'), 'Cycle end': (period.item()/2, 'r')})
        for area in ANATOMICAL_AREAS:
            oddball_band_csds[cond][band].signals[area].plot(cmap="jet_r",
                                                             title="%s-oscillation Current Source Density (%s, %s, $n=%d$)" % (latex, CONDITION_TITLES[cond], AREA_TITLES[area], oddball_band_oscillations[cond][band][area].num_trials),
                                                             filename=cond + "/%s/%s_csd.svg" % (OSCILLATORY_BAND_NAMES[band][0], AREA_TITLES[area]),
                                                             vmin=-OSCILLATORY_BAND_CBARLIMS[band], vmax=OSCILLATORY_BAND_CBARLIMS[band],
                                                             callback=functools.partial(events_callback, events={'Cycle start': (-period.item()/2, 'g'), 'Cycle end': (period.item()/2, 'r')}))
        plt.show()
# Out:
# INFO:root:Plotting oscillatory CSDs for condition lonaive
# INFO:root:Plotting oscillatory CSDs for band theta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band alphabeta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band gamma
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for condition go_gloexp
# INFO:root:Plotting oscillatory CSDs for band theta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band alphabeta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band gamma
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for condition go_seqctl
# INFO:root:Plotting oscillatory CSDs for band theta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band alphabeta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band gamma
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for condition lo_gloexp
# INFO:root:Plotting oscillatory CSDs for band theta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band alphabeta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band gamma
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for condition lo_rndctl
# INFO:root:Plotting oscillatory CSDs for band theta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band alphabeta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band gamma
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for condition igo_seqctl
# INFO:root:Plotting oscillatory CSDs for band theta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band alphabeta
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# INFO:root:Plotting oscillatory CSDs for band gamma
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]
# discrete filter coefficients:
# b = [ 0.607 1.000 0.607 ],
# a = [ 2.213 ]

# %%
for (cname, condl, condr) in CONTRASTS:
    if condl not in oddball_band_csds or condr not in oddball_band_csds:
        continue
    logging.info("Plotting oscillatory CSD contrasts for %s" % cname)
    os.makedirs(cname, exist_ok=True)
    for band, (bname, latex, _) in OSCILLATORY_BAND_NAMES.items():
        period = 1 / ((band[0] + band[1]) / 2) * pq.second
        (oddball_band_csds[condl][band] - oddball_band_csds[condr][band]).plot(
            cmap='PiYG_r', title="%s-oscillation CSD (%s)" % (latex, CONTRAST_TITLES[cname]), figure=cname + "/%s_csd.svg" % bname,
            vmin=-OSCILLATORY_BAND_CBARLIMS[band] / 2, vmax=OSCILLATORY_BAND_CBARLIMS[band] / 2,
            sigtitle=lambda area, signal: AREA_TITLES[area],
            width_per_signal=OSCILLATORY_BAND_SIGNAL_WIDTH[band], **{'Cycle start': (-period.item()/2, 'g'), 'Cycle end': (period.item()/2, 'r')}
        )
# Out:
# INFO:root:Plotting oscillatory CSD contrasts for go_contrast
# INFO:root:Plotting oscillatory CSD contrasts for ssa
# INFO:root:Plotting oscillatory CSD contrasts for dd
